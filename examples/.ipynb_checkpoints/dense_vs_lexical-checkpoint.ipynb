# %%
import os
import sys
import logging
import pandas as pd
from typing import Dict

# %%
sys.path.append(os.path.dirname(os.getcwd()))
from configs import BASE_MAPPING_PATH, QANDA_FILE_READER_PATH, PIPELINE_FIELD_MAP
from client import (
    OsMlClientWrapper,
    get_client,
)
from data_process import QAndAFileReader
from main import get_ml_model, load_category
from mapping import get_base_mapping, mapping_update
from ml_models import get_remote_connector_configs, MlModel

# %%
def load_dataset_lexical(
    client: OsMlClientWrapper,
    pqa_reader: QAndAFileReader,
    config: Dict[str, str],
    delete_existing: bool,
    index_name: str,
):
    if delete_existing:
        logging.info(f"Deleting existing index {index_name}")
        client.delete_then_create_index(
            index_name=config["index_name"], settings=config["index_settings"]
        )

    logging.info("Setting up without KNN")
    client.setup_without_kNN(
        index_name=config["index_name"],
        index_settings=config["index_settings"],
    )

    for category in config["categories"]:
        load_category(
            client=client.os_client,
            pqa_reader=pqa_reader,
            category=category,
            config=config,
        )

# %%
def load_dataset_dense(
    client: OsMlClientWrapper,
    ml_model: MlModel,
    pqa_reader: QAndAFileReader,
    config: Dict[str, str],
    delete_existing: bool,
    index_name: str,
    pipeline_name: str,
):
    if delete_existing:
        logging.info(f"Deleting existing index {index_name}")
        client.delete_then_create_index(
            index_name=config["index_name"], settings=config["index_settings"]
        )

    logging.info("Setting up for KNN")
    client.setup_for_kNN(
        ml_model=ml_model,
        index_name=config["index_name"],
        pipeline_name=pipeline_name,
        index_settings=config["index_settings"],
        pipeline_field_map=config["pipeline_field_map"],
        delete_existing=delete_existing,
        embedding_type=config["embedding_type"],
    )

    for category in config["categories"]:
        load_category(
            client=client.os_client,
            pqa_reader=pqa_reader,
            category=category,
            config=config,
        )

# %%
def create_dense_index_settings(base_mapping_path, index_config):
    settings = get_base_mapping(base_mapping_path)
    pipeline_name = index_config["pipeline_name"]
    model_dimension = index_config["model_dimensions"]
    knn_settings = {
        "settings": {"index": {"knn": True}, "default_pipeline": pipeline_name},
        "mappings": {
            "properties": {
                "chunk": {"type": "text", "index": False},
                "chunk_embedding": {
                    "type": "knn_vector",
                    "dimension": model_dimension,
                },
            }
        },
    }
    mapping_update(settings, knn_settings)
    return settings

# %%
host_type = "aos"
number_of_docs = 500
dataset_path = QANDA_FILE_READER_PATH
categories = ["sheet and pillowcase sets"]

client = OsMlClientWrapper(get_client(host_type))

pqa_reader = QAndAFileReader(directory=dataset_path, max_number_of_docs=number_of_docs)
# Out:
# 2025-04-10:08:23:02,374 INFO     [base.py:258] GET https://search-opensearch-ml-quickstart-bpt2cjvxdhn7xan6ogr7pdd53m.us-west-2.es.amazonaws.com:443/ [status:200 request:0.476s]
# 2025-04-10:08:23:02,876 INFO     [base.py:258] GET https://search-opensearch-ml-quickstart-bpt2cjvxdhn7xan6ogr7pdd53m.us-west-2.es.amazonaws.com:443/_plugins/_ml/model_groups/_search [status:200 request:0.501s]

# %%
lexical_index_name = "lexical_search"

lexical_index_config = {
    "categories": categories,
    "index_name": lexical_index_name,
    "index_settings": get_base_mapping(BASE_MAPPING_PATH),
}

load_dataset_lexical(
    client,
    pqa_reader,
    lexical_index_config,
    delete_existing=True,
    index_name=lexical_index_name,
)
# Out:
# 2025-04-10:08:23:02,901 INFO     [2292998341.py:9] Deleting existing index lexical_search
# 2025-04-10:08:23:02,915 INFO     [base.py:258] HEAD https://search-opensearch-ml-quickstart-bpt2cjvxdhn7xan6ogr7pdd53m.us-west-2.es.amazonaws.com:443/lexical_search [status:200 request:0.013s]
# 2025-04-10:08:23:02,915 INFO     [os_ml_client_wrapper.py:115] Deleting index lexical_search
# 2025-04-10:08:23:03,533 INFO     [base.py:258] DELETE https://search-opensearch-ml-quickstart-bpt2cjvxdhn7xan6ogr7pdd53m.us-west-2.es.amazonaws.com:443/lexical_search [status:200 request:0.617s]
# 2025-04-10:08:23:04,778 INFO     [base.py:258] PUT https://search-opensearch-ml-quickstart-bpt2cjvxdhn7xan6ogr7pdd53m.us-west-2.es.amazonaws.com:443/lexical_search [status:200 request:1.244s]
# 2025-04-10:08:23:04,778 INFO     [os_ml_client_wrapper.py:100] idempotent_create_index response: {'acknowledged': True, 'shards_acknowledged': True, 'index': 'lexical_search'}
# 2025-04-10:08:23:04,779 INFO     [2292998341.py:14] Setting up without KNN
# 2025-04-10:08:23:04,785 INFO     [base.py:258] HEAD https://search-opensearch-ml-quickstart-bpt2cjvxdhn7xan6ogr7pdd53m.us-west-2.es.amazonaws.com:443/lexical_search [status:200 request:0.006s]
# 2025-04-10:08:23:04,786 INFO     [os_ml_client_wrapper.py:115] Deleting index lexical_search
# 2025-04-10:08:23:05,105 INFO     [base.py:258] DELETE https://search-opensearch-ml-quickstart-bpt2cjvxdhn7xan6ogr7pdd53m.us-west-2.es.amazonaws.com:443/lexical_search [status:200 request:0.319s]
# 2025-04-10:08:23:05,529 INFO     [base.py:258] PUT https://search-opensearch-ml-quickstart-bpt2cjvxdhn7xan6ogr7pdd53m.us-west-2.es.amazonaws.com:443/lexical_search [status:200 request:0.423s]
# 2025-04-10:08:23:05,529 INFO     [os_ml_client_wrapper.py:100] idempotent_create_index response: {'acknowledged': True, 'shards_acknowledged': True, 'index': 'lexical_search'}
# 2025-04-10:08:23:05,530 INFO     [main.py:168] Loading category "sheet and pillowcase sets"
# 2025-04-10:08:23:05,530 INFO     [qanda_file_reader.py:335] Processing amazon_pqa_sheet_&_pillowcase_sets.json
# 2025-04-10:08:23:05,716 INFO     [main.py:192] Category "sheet and pillowcase sets" complete. Sending 500 docs
# 2025-04-10:08:23:05,947 INFO     [base.py:258] POST https://search-opensearch-ml-quickstart-bpt2cjvxdhn7xan6ogr7pdd53m.us-west-2.es.amazonaws.com:443/_bulk [status:200 request:0.230s]
# 2025-04-10:08:23:05,967 INFO     [base.py:258] POST https://search-opensearch-ml-quickstart-bpt2cjvxdhn7xan6ogr7pdd53m.us-west-2.es.amazonaws.com:443/_bulk [status:200 request:0.018s]
# 2025-04-10:08:23:05,985 INFO     [base.py:258] POST https://search-opensearch-ml-quickstart-bpt2cjvxdhn7xan6ogr7pdd53m.us-west-2.es.amazonaws.com:443/_bulk [status:200 request:0.017s]
# 2025-04-10:08:23:06,006 INFO     [base.py:258] POST https://search-opensearch-ml-quickstart-bpt2cjvxdhn7xan6ogr7pdd53m.us-west-2.es.amazonaws.com:443/_bulk [status:200 request:0.020s]
# 2025-04-10:08:23:06,028 INFO     [base.py:258] POST https://search-opensearch-ml-quickstart-bpt2cjvxdhn7xan6ogr7pdd53m.us-west-2.es.amazonaws.com:443/_bulk [status:200 request:0.021s]
# 2025-04-10:08:23:06,048 INFO     [base.py:258] POST https://search-opensearch-ml-quickstart-bpt2cjvxdhn7xan6ogr7pdd53m.us-west-2.es.amazonaws.com:443/_bulk [status:200 request:0.019s]
# 2025-04-10:08:23:06,070 INFO     [base.py:258] POST https://search-opensearch-ml-quickstart-bpt2cjvxdhn7xan6ogr7pdd53m.us-west-2.es.amazonaws.com:443/_bulk [status:200 request:0.021s]
# 2025-04-10:08:23:06,088 INFO     [base.py:258] POST https://search-opensearch-ml-quickstart-bpt2cjvxdhn7xan6ogr7pdd53m.us-west-2.es.amazonaws.com:443/_bulk [status:200 request:0.018s]
# 2025-04-10:08:23:06,104 INFO     [base.py:258] POST https://search-opensearch-ml-quickstart-bpt2cjvxdhn7xan6ogr7pdd53m.us-west-2.es.amazonaws.com:443/_bulk [status:200 request:0.015s]
# 2025-04-10:08:23:06,120 INFO     [base.py:258] POST https://search-opensearch-ml-quickstart-bpt2cjvxdhn7xan6ogr7pdd53m.us-west-2.es.amazonaws.com:443/_bulk [status:200 request:0.015s]
# 2025-04-10:08:23:06,141 INFO     [base.py:258] POST https://search-opensearch-ml-quickstart-bpt2cjvxdhn7xan6ogr7pdd53m.us-west-2.es.amazonaws.com:443/_bulk [status:200 request:0.020s]
# 2025-04-10:08:23:06,159 INFO     [base.py:258] POST https://search-opensearch-ml-quickstart-bpt2cjvxdhn7xan6ogr7pdd53m.us-west-2.es.amazonaws.com:443/_bulk [status:200 request:0.018s]
# 2025-04-10:08:23:06,179 INFO     [base.py:258] POST https://search-opensearch-ml-quickstart-bpt2cjvxdhn7xan6ogr7pdd53m.us-west-2.es.amazonaws.com:443/_bulk [status:200 request:0.018s]
# 2025-04-10:08:23:06,199 INFO     [base.py:258] POST https://search-opensearch-ml-quickstart-bpt2cjvxdhn7xan6ogr7pdd53m.us-west-2.es.amazonaws.com:443/_bulk [status:200 request:0.019s]
# 2025-04-10:08:23:06,221 INFO     [base.py:258] POST https://search-opensearch-ml-quickstart-bpt2cjvxdhn7xan6ogr7pdd53m.us-west-2.es.amazonaws.com:443/_bulk [status:200 request:0.021s]
# 2025-04-10:08:23:06,239 INFO     [base.py:258] POST https://search-opensearch-ml-quickstart-bpt2cjvxdhn7xan6ogr7pdd53m.us-west-2.es.amazonaws.com:443/_bulk [status:200 request:0.017s]
# 2025-04-10:08:23:06,255 INFO     [base.py:258] POST https://search-opensearch-ml-quickstart-bpt2cjvxdhn7xan6ogr7pdd53m.us-west-2.es.amazonaws.com:443/_bulk [status:200 request:0.015s]
# 2025-04-10:08:23:06,274 INFO     [base.py:258] POST https://search-opensearch-ml-quickstart-bpt2cjvxdhn7xan6ogr7pdd53m.us-west-2.es.amazonaws.com:443/_bulk [status:200 request:0.017s]
# 2025-04-10:08:23:06,292 INFO     [base.py:258] POST https://search-opensearch-ml-quickstart-bpt2cjvxdhn7xan6ogr7pdd53m.us-west-2.es.amazonaws.com:443/_bulk [status:200 request:0.018s]
# 2025-04-10:08:23:06,309 INFO     [base.py:258] POST https://search-opensearch-ml-quickstart-bpt2cjvxdhn7xan6ogr7pdd53m.us-west-2.es.amazonaws.com:443/_bulk [status:200 request:0.016s]
# 2025-04-10:08:23:06,326 INFO     [base.py:258] POST https://search-opensearch-ml-quickstart-bpt2cjvxdhn7xan6ogr7pdd53m.us-west-2.es.amazonaws.com:443/_bulk [status:200 request:0.016s]
# 2025-04-10:08:23:06,342 INFO     [base.py:258] POST https://search-opensearch-ml-quickstart-bpt2cjvxdhn7xan6ogr7pdd53m.us-west-2.es.amazonaws.com:443/_bulk [status:200 request:0.015s]
# 2025-04-10:08:23:06,359 INFO     [base.py:258] POST https://search-opensearch-ml-quickstart-bpt2cjvxdhn7xan6ogr7pdd53m.us-west-2.es.amazonaws.com:443/_bulk [status:200 request:0.016s]
# 2025-04-10:08:23:06,377 INFO     [base.py:258] POST https://search-opensearch-ml-quickstart-bpt2cjvxdhn7xan6ogr7pdd53m.us-west-2.es.amazonaws.com:443/_bulk [status:200 request:0.017s]
# 2025-04-10:08:23:06,396 INFO     [base.py:258] POST https://search-opensearch-ml-quickstart-bpt2cjvxdhn7xan6ogr7pdd53m.us-west-2.es.amazonaws.com:443/_bulk [status:200 request:0.019s]
# 2025-04-10:08:23:06,414 INFO     [base.py:258] POST https://search-opensearch-ml-quickstart-bpt2cjvxdhn7xan6ogr7pdd53m.us-west-2.es.amazonaws.com:443/_bulk [status:200 request:0.017s]
# 2025-04-10:08:23:06,429 INFO     [base.py:258] POST https://search-opensearch-ml-quickstart-bpt2cjvxdhn7xan6ogr7pdd53m.us-west-2.es.amazonaws.com:443/_bulk [status:200 request:0.014s]
# 2025-04-10:08:23:06,446 INFO     [base.py:258] POST https://search-opensearch-ml-quickstart-bpt2cjvxdhn7xan6ogr7pdd53m.us-west-2.es.amazonaws.com:443/_bulk [status:200 request:0.016s]
# 2025-04-10:08:23:06,463 INFO     [base.py:258] POST https://search-opensearch-ml-quickstart-bpt2cjvxdhn7xan6ogr7pdd53m.us-west-2.es.amazonaws.com:443/_bulk [status:200 request:0.016s]
# 2025-04-10:08:23:06,480 INFO     [base.py:258] POST https://search-opensearch-ml-quickstart-bpt2cjvxdhn7xan6ogr7pdd53m.us-west-2.es.amazonaws.com:443/_bulk [status:200 request:0.016s]
# 2025-04-10:08:23:06,496 INFO     [base.py:258] POST https://search-opensearch-ml-quickstart-bpt2cjvxdhn7xan6ogr7pdd53m.us-west-2.es.amazonaws.com:443/_bulk [status:200 request:0.015s]
# 2025-04-10:08:23:06,515 INFO     [base.py:258] POST https://search-opensearch-ml-quickstart-bpt2cjvxdhn7xan6ogr7pdd53m.us-west-2.es.amazonaws.com:443/_bulk [status:200 request:0.019s]
# 2025-04-10:08:23:06,544 INFO     [base.py:258] POST https://search-opensearch-ml-quickstart-bpt2cjvxdhn7xan6ogr7pdd53m.us-west-2.es.amazonaws.com:443/_bulk [status:200 request:0.028s]
# 2025-04-10:08:23:06,562 INFO     [base.py:258] POST https://search-opensearch-ml-quickstart-bpt2cjvxdhn7xan6ogr7pdd53m.us-west-2.es.amazonaws.com:443/_bulk [status:200 request:0.017s]
# 2025-04-10:08:23:06,582 INFO     [base.py:258] POST https://search-opensearch-ml-quickstart-bpt2cjvxdhn7xan6ogr7pdd53m.us-west-2.es.amazonaws.com:443/_bulk [status:200 request:0.019s]
# 2025-04-10:08:23:06,599 INFO     [base.py:258] POST https://search-opensearch-ml-quickstart-bpt2cjvxdhn7xan6ogr7pdd53m.us-west-2.es.amazonaws.com:443/_bulk [status:200 request:0.016s]
# 2025-04-10:08:23:06,618 INFO     [base.py:258] POST https://search-opensearch-ml-quickstart-bpt2cjvxdhn7xan6ogr7pdd53m.us-west-2.es.amazonaws.com:443/_bulk [status:200 request:0.018s]
# 2025-04-10:08:23:06,636 INFO     [base.py:258] POST https://search-opensearch-ml-quickstart-bpt2cjvxdhn7xan6ogr7pdd53m.us-west-2.es.amazonaws.com:443/_bulk [status:200 request:0.018s]
# 2025-04-10:08:23:06,659 INFO     [base.py:258] POST https://search-opensearch-ml-quickstart-bpt2cjvxdhn7xan6ogr7pdd53m.us-west-2.es.amazonaws.com:443/_bulk [status:200 request:0.021s]
# 2025-04-10:08:23:06,678 INFO     [base.py:258] POST https://search-opensearch-ml-quickstart-bpt2cjvxdhn7xan6ogr7pdd53m.us-west-2.es.amazonaws.com:443/_bulk [status:200 request:0.018s]
# 2025-04-10:08:23:06,697 INFO     [base.py:258] POST https://search-opensearch-ml-quickstart-bpt2cjvxdhn7xan6ogr7pdd53m.us-west-2.es.amazonaws.com:443/_bulk [status:200 request:0.017s]
# 2025-04-10:08:23:06,715 INFO     [base.py:258] POST https://search-opensearch-ml-quickstart-bpt2cjvxdhn7xan6ogr7pdd53m.us-west-2.es.amazonaws.com:443/_bulk [status:200 request:0.017s]
# 2025-04-10:08:23:06,733 INFO     [base.py:258] POST https://search-opensearch-ml-quickstart-bpt2cjvxdhn7xan6ogr7pdd53m.us-west-2.es.amazonaws.com:443/_bulk [status:200 request:0.018s]
# 2025-04-10:08:23:06,750 INFO     [base.py:258] POST https://search-opensearch-ml-quickstart-bpt2cjvxdhn7xan6ogr7pdd53m.us-west-2.es.amazonaws.com:443/_bulk [status:200 request:0.017s]
# 2025-04-10:08:23:06,766 INFO     [base.py:258] POST https://search-opensearch-ml-quickstart-bpt2cjvxdhn7xan6ogr7pdd53m.us-west-2.es.amazonaws.com:443/_bulk [status:200 request:0.015s]
# 2025-04-10:08:23:06,786 INFO     [base.py:258] POST https://search-opensearch-ml-quickstart-bpt2cjvxdhn7xan6ogr7pdd53m.us-west-2.es.amazonaws.com:443/_bulk [status:200 request:0.018s]
# 2025-04-10:08:23:06,804 INFO     [base.py:258] POST https://search-opensearch-ml-quickstart-bpt2cjvxdhn7xan6ogr7pdd53m.us-west-2.es.amazonaws.com:443/_bulk [status:200 request:0.017s]
# 2025-04-10:08:23:06,826 INFO     [base.py:258] POST https://search-opensearch-ml-quickstart-bpt2cjvxdhn7xan6ogr7pdd53m.us-west-2.es.amazonaws.com:443/_bulk [status:200 request:0.021s]
# 2025-04-10:08:23:06,844 INFO     [base.py:258] POST https://search-opensearch-ml-quickstart-bpt2cjvxdhn7xan6ogr7pdd53m.us-west-2.es.amazonaws.com:443/_bulk [status:200 request:0.016s]
# 2025-04-10:08:23:06,871 INFO     [base.py:258] POST https://search-opensearch-ml-quickstart-bpt2cjvxdhn7xan6ogr7pdd53m.us-west-2.es.amazonaws.com:443/_bulk [status:200 request:0.027s]

# %%
embedding_type = "dense"
dense_model_type = "sagemaker"
dense_index_name = "dense_search"
dense_model_name = "Sagemaker Dense Model"
dense_pipeline_name = "dense_embedding_pipeline"

dense_index_config = {
    "with_knn": True,
    "categories": categories,
    "index_name": dense_index_name,
    "embedding_type": embedding_type,
    "pipeline_name": dense_pipeline_name,
    "pipeline_field_map": PIPELINE_FIELD_MAP,
}

dense_model_config = get_remote_connector_configs(
    host_type=host_type, connector_type=dense_model_type
)
dense_model_config["model_name"] = dense_model_name
dense_model_config["embedding_type"] = embedding_type

dense_index_config.update(dense_model_config)

dense_model = get_ml_model(
    client=client,
    host_type=host_type,
    model_type=dense_model_type,
    model_config=dense_model_config,
)

dense_index_config["index_settings"] = create_dense_index_settings(
    base_mapping_path=BASE_MAPPING_PATH,
    index_config=dense_index_config,
)

load_dataset_dense(
    client,
    dense_model,
    pqa_reader,
    dense_index_config,
    delete_existing=True,
    index_name=dense_index_name,
    pipeline_name=dense_pipeline_name,
)
# Out:
# 2025-04-10:08:23:06,950 INFO     [credentials.py:1278] Found credentials in shared credentials file: ~/.aws/credentials
# 2025-04-10:08:23:07,204 INFO     [base.py:258] POST https://search-opensearch-ml-quickstart-bpt2cjvxdhn7xan6ogr7pdd53m.us-west-2.es.amazonaws.com:443/_plugins/_ml/connectors/_search [status:200 request:0.007s]
# 2025-04-10:08:23:07,210 INFO     [base.py:258] POST https://search-opensearch-ml-quickstart-bpt2cjvxdhn7xan6ogr7pdd53m.us-west-2.es.amazonaws.com:443/_plugins/_ml/connectors/_search [status:200 request:0.005s]
# 2025-04-10:08:23:07,211 INFO     [ml_connector.py:38] Connector id 0gJSHpYBdIibWvQqjx9b
# 2025-04-10:08:23:07,217 INFO     [base.py:258] POST https://search-opensearch-ml-quickstart-bpt2cjvxdhn7xan6ogr7pdd53m.us-west-2.es.amazonaws.com:443/_plugins/_ml/models/_search [status:200 request:0.006s]
# 2025-04-10:08:23:07,223 INFO     [base.py:258] POST https://search-opensearch-ml-quickstart-bpt2cjvxdhn7xan6ogr7pdd53m.us-west-2.es.amazonaws.com:443/_plugins/_ml/models/_search [status:200 request:0.005s]
# 2025-04-10:08:23:07,224 INFO     [ml_model.py:34] MlModel id CY9SHpYBMwhocUpVjzmQ
# 2025-04-10:08:23:07,224 INFO     [3013162640.py:11] Deleting existing index dense_search
# 2025-04-10:08:23:07,231 INFO     [base.py:258] HEAD https://search-opensearch-ml-quickstart-bpt2cjvxdhn7xan6ogr7pdd53m.us-west-2.es.amazonaws.com:443/dense_search [status:200 request:0.006s]
# 2025-04-10:08:23:07,231 INFO     [os_ml_client_wrapper.py:115] Deleting index dense_search
# 2025-04-10:08:23:07,454 INFO     [base.py:258] DELETE https://search-opensearch-ml-quickstart-bpt2cjvxdhn7xan6ogr7pdd53m.us-west-2.es.amazonaws.com:443/dense_search [status:200 request:0.223s]
# 2025-04-10:08:23:07,873 INFO     [base.py:258] PUT https://search-opensearch-ml-quickstart-bpt2cjvxdhn7xan6ogr7pdd53m.us-west-2.es.amazonaws.com:443/dense_search [status:200 request:0.418s]
# 2025-04-10:08:23:07,874 INFO     [os_ml_client_wrapper.py:100] idempotent_create_index response: {'acknowledged': True, 'shards_acknowledged': True, 'index': 'dense_search'}
# 2025-04-10:08:23:07,874 INFO     [3013162640.py:16] Setting up for KNN
# 2025-04-10:08:23:07,874 INFO     [os_ml_client_wrapper.py:132] Setup for KNN; ml model: CY9SHpYBMwhocUpVjzmQ; ml model group: uo8eg5UBMwhocUpVdCPB
# 2025-04-10:08:23:07,878 WARNING  [base.py:280] PUT https://search-opensearch-ml-quickstart-bpt2cjvxdhn7xan6ogr7pdd53m.us-west-2.es.amazonaws.com:443/_cluster/settings [status:401 request:0.003s]
# 2025-04-10:08:23:07,878 INFO     [os_ml_client_wrapper.py:148] Setting up cluster settings failed due to exception AuthenticationException(401, '{"Message":"Your request: \'/_cluster/settings\' payload is not allowed."}')
# 2025-04-10:08:23:08,035 INFO     [base.py:258] PUT https://search-opensearch-ml-quickstart-bpt2cjvxdhn7xan6ogr7pdd53m.us-west-2.es.amazonaws.com:443/_cluster/settings [status:200 request:0.157s]
# 2025-04-10:08:23:08,042 INFO     [base.py:258] HEAD https://search-opensearch-ml-quickstart-bpt2cjvxdhn7xan6ogr7pdd53m.us-west-2.es.amazonaws.com:443/dense_search [status:200 request:0.006s]
# 2025-04-10:08:23:08,042 INFO     [os_ml_client_wrapper.py:115] Deleting index dense_search
# 2025-04-10:08:23:08,229 INFO     [base.py:258] DELETE https://search-opensearch-ml-quickstart-bpt2cjvxdhn7xan6ogr7pdd53m.us-west-2.es.amazonaws.com:443/dense_search [status:200 request:0.186s]
# 2025-04-10:08:23:08,632 INFO     [base.py:258] PUT https://search-opensearch-ml-quickstart-bpt2cjvxdhn7xan6ogr7pdd53m.us-west-2.es.amazonaws.com:443/dense_search [status:200 request:0.403s]
# 2025-04-10:08:23:08,633 INFO     [os_ml_client_wrapper.py:100] idempotent_create_index response: {'acknowledged': True, 'shards_acknowledged': True, 'index': 'dense_search'}
# 2025-04-10:08:23:08,633 INFO     [os_ml_client_wrapper.py:50] {'description': 'Pipeline for processing chunks', 'processors': [{'text_embedding': {'model_id': 'CY9SHpYBMwhocUpVjzmQ', 'field_map': {'chunk': 'chunk_embedding'}}}]}
# 2025-04-10:08:23:08,634 INFO     [os_ml_client_wrapper.py:76] dense_pipeline_config: {'chunk': 'chunk_embedding'}
# 2025-04-10:08:23:08,634 INFO     [os_ml_client_wrapper.py:77] Adding dense pipeline...
# 2025-04-10:08:23:08,889 INFO     [base.py:258] PUT https://search-opensearch-ml-quickstart-bpt2cjvxdhn7xan6ogr7pdd53m.us-west-2.es.amazonaws.com:443/_ingest/pipeline/dense_embedding_pipeline [status:200 request:0.255s]
# 2025-04-10:08:23:08,890 INFO     [main.py:168] Loading category "sheet and pillowcase sets"
# 2025-04-10:08:23:08,890 INFO     [qanda_file_reader.py:335] Processing amazon_pqa_sheet_&_pillowcase_sets.json
# 2025-04-10:08:23:09,076 INFO     [main.py:192] Category "sheet and pillowcase sets" complete. Sending 500 docs
# 2025-04-10:08:23:09,242 INFO     [base.py:258] POST https://search-opensearch-ml-quickstart-bpt2cjvxdhn7xan6ogr7pdd53m.us-west-2.es.amazonaws.com:443/_bulk [status:200 request:0.165s]
# 2025-04-10:08:23:09,344 INFO     [base.py:258] POST https://search-opensearch-ml-quickstart-bpt2cjvxdhn7xan6ogr7pdd53m.us-west-2.es.amazonaws.com:443/_bulk [status:200 request:0.101s]
# 2025-04-10:08:23:09,418 INFO     [base.py:258] POST https://search-opensearch-ml-quickstart-bpt2cjvxdhn7xan6ogr7pdd53m.us-west-2.es.amazonaws.com:443/_bulk [status:200 request:0.073s]
# 2025-04-10:08:23:09,512 INFO     [base.py:258] POST https://search-opensearch-ml-quickstart-bpt2cjvxdhn7xan6ogr7pdd53m.us-west-2.es.amazonaws.com:443/_bulk [status:200 request:0.093s]
# 2025-04-10:08:23:09,590 INFO     [base.py:258] POST https://search-opensearch-ml-quickstart-bpt2cjvxdhn7xan6ogr7pdd53m.us-west-2.es.amazonaws.com:443/_bulk [status:200 request:0.078s]
# 2025-04-10:08:23:09,673 INFO     [base.py:258] POST https://search-opensearch-ml-quickstart-bpt2cjvxdhn7xan6ogr7pdd53m.us-west-2.es.amazonaws.com:443/_bulk [status:200 request:0.081s]
# 2025-04-10:08:23:09,747 INFO     [base.py:258] POST https://search-opensearch-ml-quickstart-bpt2cjvxdhn7xan6ogr7pdd53m.us-west-2.es.amazonaws.com:443/_bulk [status:200 request:0.073s]
# 2025-04-10:08:23:09,824 INFO     [base.py:258] POST https://search-opensearch-ml-quickstart-bpt2cjvxdhn7xan6ogr7pdd53m.us-west-2.es.amazonaws.com:443/_bulk [status:200 request:0.077s]
# 2025-04-10:08:23:09,893 INFO     [base.py:258] POST https://search-opensearch-ml-quickstart-bpt2cjvxdhn7xan6ogr7pdd53m.us-west-2.es.amazonaws.com:443/_bulk [status:200 request:0.068s]
# 2025-04-10:08:23:09,962 INFO     [base.py:258] POST https://search-opensearch-ml-quickstart-bpt2cjvxdhn7xan6ogr7pdd53m.us-west-2.es.amazonaws.com:443/_bulk [status:200 request:0.068s]
# 2025-04-10:08:23:10,045 INFO     [base.py:258] POST https://search-opensearch-ml-quickstart-bpt2cjvxdhn7xan6ogr7pdd53m.us-west-2.es.amazonaws.com:443/_bulk [status:200 request:0.082s]
# 2025-04-10:08:23:10,119 INFO     [base.py:258] POST https://search-opensearch-ml-quickstart-bpt2cjvxdhn7xan6ogr7pdd53m.us-west-2.es.amazonaws.com:443/_bulk [status:200 request:0.073s]
# 2025-04-10:08:23:10,190 INFO     [base.py:258] POST https://search-opensearch-ml-quickstart-bpt2cjvxdhn7xan6ogr7pdd53m.us-west-2.es.amazonaws.com:443/_bulk [status:200 request:0.070s]
# 2025-04-10:08:23:10,265 INFO     [base.py:258] POST https://search-opensearch-ml-quickstart-bpt2cjvxdhn7xan6ogr7pdd53m.us-west-2.es.amazonaws.com:443/_bulk [status:200 request:0.074s]
# 2025-04-10:08:23:10,350 INFO     [base.py:258] POST https://search-opensearch-ml-quickstart-bpt2cjvxdhn7xan6ogr7pdd53m.us-west-2.es.amazonaws.com:443/_bulk [status:200 request:0.083s]
# 2025-04-10:08:23:10,423 INFO     [base.py:258] POST https://search-opensearch-ml-quickstart-bpt2cjvxdhn7xan6ogr7pdd53m.us-west-2.es.amazonaws.com:443/_bulk [status:200 request:0.072s]
# 2025-04-10:08:23:10,493 INFO     [base.py:258] POST https://search-opensearch-ml-quickstart-bpt2cjvxdhn7xan6ogr7pdd53m.us-west-2.es.amazonaws.com:443/_bulk [status:200 request:0.069s]
# 2025-04-10:08:23:10,566 INFO     [base.py:258] POST https://search-opensearch-ml-quickstart-bpt2cjvxdhn7xan6ogr7pdd53m.us-west-2.es.amazonaws.com:443/_bulk [status:200 request:0.073s]
# 2025-04-10:08:23:10,642 INFO     [base.py:258] POST https://search-opensearch-ml-quickstart-bpt2cjvxdhn7xan6ogr7pdd53m.us-west-2.es.amazonaws.com:443/_bulk [status:200 request:0.074s]
# 2025-04-10:08:23:10,712 INFO     [base.py:258] POST https://search-opensearch-ml-quickstart-bpt2cjvxdhn7xan6ogr7pdd53m.us-west-2.es.amazonaws.com:443/_bulk [status:200 request:0.070s]
# 2025-04-10:08:23:10,778 INFO     [base.py:258] POST https://search-opensearch-ml-quickstart-bpt2cjvxdhn7xan6ogr7pdd53m.us-west-2.es.amazonaws.com:443/_bulk [status:200 request:0.064s]
# 2025-04-10:08:23:10,843 INFO     [base.py:258] POST https://search-opensearch-ml-quickstart-bpt2cjvxdhn7xan6ogr7pdd53m.us-west-2.es.amazonaws.com:443/_bulk [status:200 request:0.065s]
# 2025-04-10:08:23:10,910 INFO     [base.py:258] POST https://search-opensearch-ml-quickstart-bpt2cjvxdhn7xan6ogr7pdd53m.us-west-2.es.amazonaws.com:443/_bulk [status:200 request:0.066s]
# 2025-04-10:08:23:10,985 INFO     [base.py:258] POST https://search-opensearch-ml-quickstart-bpt2cjvxdhn7xan6ogr7pdd53m.us-west-2.es.amazonaws.com:443/_bulk [status:200 request:0.073s]
# 2025-04-10:08:23:11,064 INFO     [base.py:258] POST https://search-opensearch-ml-quickstart-bpt2cjvxdhn7xan6ogr7pdd53m.us-west-2.es.amazonaws.com:443/_bulk [status:200 request:0.078s]
# 2025-04-10:08:23:11,136 INFO     [base.py:258] POST https://search-opensearch-ml-quickstart-bpt2cjvxdhn7xan6ogr7pdd53m.us-west-2.es.amazonaws.com:443/_bulk [status:200 request:0.071s]
# 2025-04-10:08:23:11,203 INFO     [base.py:258] POST https://search-opensearch-ml-quickstart-bpt2cjvxdhn7xan6ogr7pdd53m.us-west-2.es.amazonaws.com:443/_bulk [status:200 request:0.065s]
# 2025-04-10:08:23:11,274 INFO     [base.py:258] POST https://search-opensearch-ml-quickstart-bpt2cjvxdhn7xan6ogr7pdd53m.us-west-2.es.amazonaws.com:443/_bulk [status:200 request:0.070s]
# 2025-04-10:08:23:11,344 INFO     [base.py:258] POST https://search-opensearch-ml-quickstart-bpt2cjvxdhn7xan6ogr7pdd53m.us-west-2.es.amazonaws.com:443/_bulk [status:200 request:0.070s]
# 2025-04-10:08:23:11,416 INFO     [base.py:258] POST https://search-opensearch-ml-quickstart-bpt2cjvxdhn7xan6ogr7pdd53m.us-west-2.es.amazonaws.com:443/_bulk [status:200 request:0.071s]
# 2025-04-10:08:23:11,481 INFO     [base.py:258] POST https://search-opensearch-ml-quickstart-bpt2cjvxdhn7xan6ogr7pdd53m.us-west-2.es.amazonaws.com:443/_bulk [status:200 request:0.064s]
# 2025-04-10:08:23:11,553 INFO     [base.py:258] POST https://search-opensearch-ml-quickstart-bpt2cjvxdhn7xan6ogr7pdd53m.us-west-2.es.amazonaws.com:443/_bulk [status:200 request:0.071s]
# 2025-04-10:08:23:11,628 INFO     [base.py:258] POST https://search-opensearch-ml-quickstart-bpt2cjvxdhn7xan6ogr7pdd53m.us-west-2.es.amazonaws.com:443/_bulk [status:200 request:0.073s]
# 2025-04-10:08:23:11,696 INFO     [base.py:258] POST https://search-opensearch-ml-quickstart-bpt2cjvxdhn7xan6ogr7pdd53m.us-west-2.es.amazonaws.com:443/_bulk [status:200 request:0.067s]
# 2025-04-10:08:23:11,768 INFO     [base.py:258] POST https://search-opensearch-ml-quickstart-bpt2cjvxdhn7xan6ogr7pdd53m.us-west-2.es.amazonaws.com:443/_bulk [status:200 request:0.071s]
# 2025-04-10:08:23:11,839 INFO     [base.py:258] POST https://search-opensearch-ml-quickstart-bpt2cjvxdhn7xan6ogr7pdd53m.us-west-2.es.amazonaws.com:443/_bulk [status:200 request:0.070s]
# 2025-04-10:08:23:11,912 INFO     [base.py:258] POST https://search-opensearch-ml-quickstart-bpt2cjvxdhn7xan6ogr7pdd53m.us-west-2.es.amazonaws.com:443/_bulk [status:200 request:0.072s]
# 2025-04-10:08:23:11,984 INFO     [base.py:258] POST https://search-opensearch-ml-quickstart-bpt2cjvxdhn7xan6ogr7pdd53m.us-west-2.es.amazonaws.com:443/_bulk [status:200 request:0.071s]
# 2025-04-10:08:23:12,064 INFO     [base.py:258] POST https://search-opensearch-ml-quickstart-bpt2cjvxdhn7xan6ogr7pdd53m.us-west-2.es.amazonaws.com:443/_bulk [status:200 request:0.079s]
# 2025-04-10:08:23:12,138 INFO     [base.py:258] POST https://search-opensearch-ml-quickstart-bpt2cjvxdhn7xan6ogr7pdd53m.us-west-2.es.amazonaws.com:443/_bulk [status:200 request:0.073s]
# 2025-04-10:08:23:12,212 INFO     [base.py:258] POST https://search-opensearch-ml-quickstart-bpt2cjvxdhn7xan6ogr7pdd53m.us-west-2.es.amazonaws.com:443/_bulk [status:200 request:0.073s]
# 2025-04-10:08:23:12,283 INFO     [base.py:258] POST https://search-opensearch-ml-quickstart-bpt2cjvxdhn7xan6ogr7pdd53m.us-west-2.es.amazonaws.com:443/_bulk [status:200 request:0.070s]
# 2025-04-10:08:23:12,352 INFO     [base.py:258] POST https://search-opensearch-ml-quickstart-bpt2cjvxdhn7xan6ogr7pdd53m.us-west-2.es.amazonaws.com:443/_bulk [status:200 request:0.068s]
# 2025-04-10:08:23:12,423 INFO     [base.py:258] POST https://search-opensearch-ml-quickstart-bpt2cjvxdhn7xan6ogr7pdd53m.us-west-2.es.amazonaws.com:443/_bulk [status:200 request:0.070s]
# 2025-04-10:08:23:12,490 INFO     [base.py:258] POST https://search-opensearch-ml-quickstart-bpt2cjvxdhn7xan6ogr7pdd53m.us-west-2.es.amazonaws.com:443/_bulk [status:200 request:0.066s]
# 2025-04-10:08:23:12,563 INFO     [base.py:258] POST https://search-opensearch-ml-quickstart-bpt2cjvxdhn7xan6ogr7pdd53m.us-west-2.es.amazonaws.com:443/_bulk [status:200 request:0.071s]
# 2025-04-10:08:23:12,634 INFO     [base.py:258] POST https://search-opensearch-ml-quickstart-bpt2cjvxdhn7xan6ogr7pdd53m.us-west-2.es.amazonaws.com:443/_bulk [status:200 request:0.071s]
# 2025-04-10:08:23:12,710 INFO     [base.py:258] POST https://search-opensearch-ml-quickstart-bpt2cjvxdhn7xan6ogr7pdd53m.us-west-2.es.amazonaws.com:443/_bulk [status:200 request:0.074s]
# 2025-04-10:08:23:12,779 INFO     [base.py:258] POST https://search-opensearch-ml-quickstart-bpt2cjvxdhn7xan6ogr7pdd53m.us-west-2.es.amazonaws.com:443/_bulk [status:200 request:0.068s]
# 2025-04-10:08:23:12,854 INFO     [base.py:258] POST https://search-opensearch-ml-quickstart-bpt2cjvxdhn7xan6ogr7pdd53m.us-west-2.es.amazonaws.com:443/_bulk [status:200 request:0.074s]

# %%
query_text = "The most beautiful pillow"
search_size = 50

lexical_search_query = {
    "size": search_size,
    "_source": {"include": "chunk"},
    "query": {"match": {"chunk": query_text}},
}
dense_search_query = {
    "size": search_size,
    "_source": {"include": "chunk"},
    "query": {
        "neural": {
            "chunk_embedding": {
                "k": search_size,
                "query_text": query_text,
                "model_id": dense_model.model_id(),
            }
        }
    },
}

# %%
lexical_search_results = client.os_client.search(
    index=lexical_index_name, body=lexical_search_query
)

dense_search_results = client.os_client.search(
    index=dense_index_name, body=dense_search_query
)

lexical_hits = lexical_search_results["hits"]["hits"]
lexical_hits = [lexical_hit["_source"]["chunk"] for lexical_hit in lexical_hits]
lexical_hits = list(set(lexical_hits))

dense_hits = dense_search_results["hits"]["hits"]
dense_hits = [dense_hit["_source"]["chunk"] for dense_hit in dense_hits]
dense_hits = list(set(dense_hits))
# Out:
# 2025-04-10:08:23:12,878 INFO     [base.py:258] POST https://search-opensearch-ml-quickstart-bpt2cjvxdhn7xan6ogr7pdd53m.us-west-2.es.amazonaws.com:443/lexical_search/_search [status:200 request:0.013s]
# 2025-04-10:08:23:12,925 INFO     [base.py:258] POST https://search-opensearch-ml-quickstart-bpt2cjvxdhn7xan6ogr7pdd53m.us-west-2.es.amazonaws.com:443/dense_search/_search [status:200 request:0.046s]

# %%
top10_dense_hits, top10_lexical_hits = dense_hits[:10], lexical_hits[:10]

df = pd.DataFrame(
    {
        "top 10 dense search results": top10_dense_hits,
        "top 10 lexical search results": top10_lexical_hits,
    }
)

# %%
from IPython.display import display, HTML

# Create a title and style the DataFrame
styled_df = (
    df.style.set_caption(f"Search Results from query: {query_text}")
    .set_table_styles(
        [
            {
                "selector": "caption",
                "props": [
                    ("text-align", "center"),
                    ("font-size", "20px"),
                    ("font-weight", "bold"),
                    ("color", "#333333"),
                    ("background-color", "#f0f0f0"),
                    ("padding", "10px"),
                ],
            },
            {
                "selector": "th",
                "props": [
                    ("font-size", "16px"),
                    ("text-align", "center"),
                    ("background-color", "#4472C4"),
                    ("color", "white"),
                    ("font-weight", "bold"),
                    ("padding", "10px"),
                ],
            },
            {
                "selector": "td",
                "props": [
                    ("font-size", "14px"),
                    ("padding", "8px"),
                    ("border", "1px solid #ddd"),
                ],
            },
            {
                "selector": "tr:nth-of-type(odd)",
                "props": [("background-color", "#f9f9f9")],
            },
        ]
    )
    .format_index(str.upper, axis=1)
    .relabel_index([str(num) for num in range(1, 11)], axis=0)
    .set_properties(**{"max-width": "800px", "white-space": "pre-wrap"})
)

# Display the styled DataFrame with increased size
display(HTML("<style>.rendered_html table {font-size: 16px; width: 100%;}</style>"))
display(styled_df)
# Out:
# <style>.rendered_html table {font-size: 16px; width: 100%;}</style>
# <style type="text/css">
# #T_18b69 caption {
#   text-align: center;
#   font-size: 20px;
#   font-weight: bold;
#   color: #333333;
#   background-color: #f0f0f0;
#   padding: 10px;
# }
# #T_18b69 th {
#   font-size: 16px;
#   text-align: center;
#   background-color: #4472C4;
#   color: white;
#   font-weight: bold;
#   padding: 10px;
# }
# #T_18b69 td {
#   font-size: 14px;
#   padding: 8px;
#   border: 1px solid #ddd;
# }
# #T_18b69 tr:nth-of-type(odd) {
#   background-color: #f9f9f9;
# }
# #T_18b69_row0_col0, #T_18b69_row0_col1, #T_18b69_row1_col0, #T_18b69_row1_col1, #T_18b69_row2_col0, #T_18b69_row2_col1, #T_18b69_row3_col0, #T_18b69_row3_col1, #T_18b69_row4_col0, #T_18b69_row4_col1, #T_18b69_row5_col0, #T_18b69_row5_col1, #T_18b69_row6_col0, #T_18b69_row6_col1, #T_18b69_row7_col0, #T_18b69_row7_col1, #T_18b69_row8_col0, #T_18b69_row8_col1, #T_18b69_row9_col0, #T_18b69_row9_col1 {
#   max-width: 800px;
#   white-space: pre-wrap;
# }
# </style>
# <table id="T_18b69">
#   <caption>Search Results from query: The most beautiful pillow</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_18b69_level0_col0" class="col_heading level0 col0" >TOP 10 DENSE SEARCH RESULTS</th>
#       <th id="T_18b69_level0_col1" class="col_heading level0 col1" >TOP 10 LEXICAL SEARCH RESULTS</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_18b69_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_18b69_row0_col0" class="data row0 col0" >Wrap yourself in the Softness of the luxurious 100% cotton CRISPY PERCALE SHEETS like those found in World Class Hotels. These fine luxury bed linens are crafted from long staple cotton with Traditional, Original, Crisp, Breathable Percale Weave for a real good and healthy sleep. Comfort, quality and opulence set our luxury bedding in a class above the rest. Elegant yet durable, their softness is enhanced with each washing. If you have never experienced the luxury and elegance of high quality Crispy Percale sheets.... try it! There is a difference ! Royal Hotel Abripedic Crispy Percale Sheets, 300-Thread-Count, 4PC Solid Sheet Set, 100% Cotton, 22 Inch Super Deep Pocket, California-King, Gray</td>
#       <td id="T_18b69_row0_col1" class="data row0 col1" >Mellanni 100% Cotton 300 Thread Count Percale 4 Piece Bed Sheet Set#1 Bed Sheet Set - HIGHEST QUALITY - Deep Pocket, Breathable, Durable, Fade Resistant BeddingFeatures and Benefits:OEKO TEX CERTIFIED to keep your family healthy and safe from chemicalsCRISP AND AIRYfor an ultra luxurious feel and exceptional comfort. Sleep better and wake up each morning feeling refreshed and full of energy.VERSATILE - Perfect for any room in your house - bedroom, guest room, kids room, RV, vacation home, camping. Great bed in a bag additionPERFECT GIFT for Everyone - Men, women and children. Great for any occasion - Valentine's, Mother's, Father's Day and ChristmasDEEP POCKET - fits mattresses up to 16 . Fitted sheet with elastic all aroundEASY CARE - machine wash cold gentle cycle, tumble dry lowGETS SOFTER with every wash for an additional comfortSize Guide:Twin size - Flat sheet 66 x 96 inches, Fitted sheet 39 x 75 inches, 1 Pillow case 20 x 30 inchesTwin XL size - Flat sheet 66 x 96 inches, Fitted sheet 39 x 80 inches, 1 Pillow case 20 x 30 inchesFull size - Flat sheet 82 x 96 inches, Fitted sheet 54 x 75 inches, 2 Pillow cases 20 x 30 inchesQueen size - flat sheet 90 x 102 inches, fitted sheet 60 x 80 inches, 2 pillow cases 20 x 30 inchesKing size - Flat sheet 102 x 108 inches, Fitted sheet 78 x 80 inches, 2 Pillow cases 20 x 40 inchesCalifornia King size - Flat sheet 102 x 108 inches, Fitted sheet 72 x 84 inches, 2 Pillow cases 20 x 40 inchesThe Best Unconditional Lifetime Guarantee, Included For Free!Our 100% no questions asked, no hassle money back or replacement guarantee is the best in the business. Order now!" Mellanni 100% Cotton Bed Sheet Set - 300 Thread Count Percale - Deep Pocket - Quality Luxury Bedding - 4 Piece (Cal King, Gray)</td>
#     </tr>
#     <tr>
#       <th id="T_18b69_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_18b69_row1_col0" class="data row1 col0" >#1 Bed Sheet Set - Super Silky Soft - HIGHEST QUALITY 100% Brushed Microfiber Striped 1800 Bedding CollectionsWrinkle, Fade, Stain Resistant - Deep Pockets - Luxury Fitted & Flat Sheets, PillowcasesBest For Bedroom, Guest Room, Childrens Room, RV, Vacation Home, Bed in a Bag Addition - LIFETIME GUARANTEEMellanni Fine Linens wraps you in elegance, luxury and comfort. Indulge in silky soft, 100% brushed microfiber carefully crafted in every detailHere’s What A Few Of Our Raving Fans Are Saying“Softest Sheets EVER!” “Best sheets I've ever slept on” “Best customer service on Amazon, Period” “Beats any other product”Microfiber sheets are breathable, keep moisture away. Comes in Twin, Twin XL, Full, Queen, King, Split King and California King.Perfect bedding sets for adults, kids, toddler, teen girls and boys.These luxuries bed sheets stay fresh, cool during hot nights and warm in cold nights - leaving you and your family rested and ready for a new day.Extremely soft and comfortable!The Best Unconditional Lifetime Guarantee, Included For Free!Our 100% no questions asked, no hassle money back or replacement guarantee is the best in the business. Order now! Mellanni Striped Bed Sheet Set - Brushed Microfiber 1800 Bedding - Wrinkle, Fade, Stain Resistant - 4 Piece (King, Light Blue)</td>
#       <td id="T_18b69_row1_col1" class="data row1 col1" >Livenza 100 % Egyptian Cotton sheets with comfort, luxury and style a cut above the rest. Beautiful sheet that feel great, look great, and launder like a dream. You'll love sleeping on this fabulous bedding. Elegant yet durable, their softness is enhanced with each washing. You will relax and enjoy the rich, soft and luxurious feeling of cotton sheets. These sheets available in Both solid and stripe patterned bedding. Set include one, Fitted sheet ,one Flat sheet and two, pillowcases only. Our sheets are woven dyed and sewn with specific standards and requirements that produce excellence. Each one of us spends about one-third of our lives in our bed. Sleep plays a vital role in our good health and well-being throughout our lives. Getting enough quality sleep can help protect your mental health, physical health, quality of life, and safety. We are excited to bring you luxury in the endeavor to make your overall health the best it can be. Endeavor Our Livenza Collections 100% Egyptian Cotton has a feeling of relaxation, peace, luxury and comfort within its threads. Here's to peaceful, ultimate Sleep.Click on Add to Cart " and Thank You for Buying " Livenza Exclusive Collection 100% Egyptian Cotton Sheet Set fits mattresses up to 19 deep 1000 TC Color-White Solid Size Queen"</td>
#     </tr>
#     <tr>
#       <th id="T_18b69_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_18b69_row2_col0" class="data row2 col0" >Livenza 100 % Egyptian Cotton sheets with comfort, luxury and style a cut above the rest. Beautiful sheet that feel great, look great, and launder like a dream. You'll love sleeping on this fabulous bedding. Elegant yet durable, their softness is enhanced with each washing. You will relax and enjoy the rich, soft and luxurious feeling of cotton sheets. These sheets available in Both solid and stripe patterned bedding. Set include one, Fitted sheet ,one Flat sheet and two, pillowcases only. Our sheets are woven dyed and sewn with specific standards and requirements that produce excellence. Each one of us spends about one-third of our lives in our bed. Sleep plays a vital role in our good health and well-being throughout our lives. Getting enough quality sleep can help protect your mental health, physical health, quality of life, and safety. We are excited to bring you luxury in the endeavor to make your overall health the best it can be. Endeavor Our Livenza Collections 100% Egyptian Cotton has a feeling of relaxation, peace, luxury and comfort within its t
